# %% [markdown]
# ## Prerequisites

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data preperation

# %%
# read train data
emotion_train = pd.read_csv("../data/emotions/train.txt", delimiter=';', header=None, names=['Sentence','Label'])

# %%
# show first 5 rows
emotion_train.head()
# Out:
#                                             Sentence    Label
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
# data frame details
emotion_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  16000 non-null  object
#  1   Label     16000 non-null  object
# dtypes: object(2)
# memory usage: 250.1+ KB

# %%
emotion_train.shape
# Out:
# (16000, 2)

# %%
# all unique labels
emotion_train.Label.unique()
# Out:
# array(['sadness', 'anger', 'love', 'surprise', 'fear', 'joy'],
#       dtype=object)

# %% [markdown]
# ## Clean the emojis dataset

# %%
# read the second dataset
emojis = pd.read_csv("../data/emojis/Emoji_Sentiment_Data_v1.0.csv")

# %%
emojis.head()
# we need the emoji itself - to return as output
# we need the name of the emoji - to match with input message
# we need the number of occurrences - the emoji with the highest number is suggested first (?)
# Out:
#   Emoji Unicode codepoint  Occurrences  Position  Negative  Neutral  Positive  \
# 0     😂           0x1f602        14622  0.805101      3614     4163      6845
# 1     ❤            0x2764         8050  0.746943       355     1334      6361
# 2     ♥            0x2665         7144  0.753806       252     1942      4950
# 3     😍           0x1f60d         6359  0.765292       329     1390      4640
# 4     😭           0x1f62d         5526  0.803352      2412     1218      1896
#
#                           Unicode name          Unicode block
# 0               FACE WITH TEARS OF JOY              Emoticons
# 1                    HEAVY BLACK HEART               Dingbats
# 2                     BLACK HEART SUIT  Miscellaneous Symbols
# 3  SMILING FACE WITH HEART-SHAPED EYES              Emoticons
# 4                   LOUDLY CRYING FACE              Emoticons

# %%
# create a smaller dataframe to loop through
emoji_sentiment = emojis[['Negative', 'Neutral','Positive']]
# assign each emoji with only one sentiment which is the sentiment with highest number
emojis['Sentiment'] = emoji_sentiment.apply(lambda x: emoji_sentiment.columns[x.argmax()], axis = 1)

# %%
# before
emojis.head() # we dont need all of these columns
# Out:
#   Emoji Unicode codepoint  Occurrences  Position  Negative  Neutral  Positive  \
# 0     😂           0x1f602        14622  0.805101      3614     4163      6845
# 1     ❤            0x2764         8050  0.746943       355     1334      6361
# 2     ♥            0x2665         7144  0.753806       252     1942      4950
# 3     😍           0x1f60d         6359  0.765292       329     1390      4640
# 4     😭           0x1f62d         5526  0.803352      2412     1218      1896
#
#                           Unicode name          Unicode block Sentiment
# 0               FACE WITH TEARS OF JOY              Emoticons  Positive
# 1                    HEAVY BLACK HEART               Dingbats  Positive
# 2                     BLACK HEART SUIT  Miscellaneous Symbols  Positive
# 3  SMILING FACE WITH HEART-SHAPED EYES              Emoticons  Positive
# 4                   LOUDLY CRYING FACE              Emoticons  Negative

# %%
# keep columns that we need
emojis = emojis[['Emoji', 'Occurrences', 'Unicode name', 'Sentiment']]

# %%
# after
emojis.head()
# Out:
#   Emoji  Occurrences                         Unicode name Sentiment
# 0     😂        14622               FACE WITH TEARS OF JOY  Positive
# 1     ❤         8050                    HEAVY BLACK HEART  Positive
# 2     ♥         7144                     BLACK HEART SUIT  Positive
# 3     😍         6359  SMILING FACE WITH HEART-SHAPED EYES  Positive
# 4     😭         5526                   LOUDLY CRYING FACE  Negative

# %%
# save the dataset as csv
emojis.to_csv('"../data/emojis_sentiment_cleaned.csv', index=False)

# %% [markdown]
# ## Merge the two datasets

# %%
emojis[emojis['Sentiment'] == 'Neutral']
# Out:
#     Emoji  Occurrences                                    Unicode name  \
# 17      😏         1522                                   SMIRKING FACE
# 31      ☯          992                                        YIN YANG
# 35      ✨          848                                        SPARKLES
# 38      ★          828                                      BLACK STAR
# 39      █          798                                      FULL BLOCK
# ..    ...          ...                                             ...
# 959     ♊            1                                          GEMINI
# 964     ➛            1                 DRAFTING POINT RIGHTWARDS ARROW
# 965     ♝            1                              BLACK CHESS BISHOP
# 966     ❋            1  HEAVY EIGHT TEARDROP-SPOKED PROPELLER ASTERISK
# 967     ✆            1                         TELEPHONE LOCATION SIGN
#
#     Sentiment
# 17    Neutral
# 31    Neutral
# 35    Neutral
# 38    Neutral
# 39    Neutral
# ..        ...
# 959   Neutral
# 964   Neutral
# 965   Neutral
# 966   Neutral
# 967   Neutral
#
# [380 rows x 4 columns]

# %%
# how do i match these two arrays?
# ['sadness', 'anger', 'love', 'surprise', 'fear', 'joy']
# ['Negative', 'Neutral','Positive']

### option
# ['sadnees', 'negative', 'neutral']
# ['anger', 'negative']
# ['love', 'positive', 'neutral']
# ['surprise', 'neutral']
# ['fear', 'negative']
# ['joy', 'positive', 'neutral']

# %%
# classify labels and put them in arrays 
negative_emotions = ['sadness', 'anger', 'fear']
neutral_emotions = ['sadness', 'love', 'surprise', 'joy']
positive_emotions = ['love', 'joy']
# use list comprehension to create a new column called sentiment
emotion_train['Sentiment'] = ['Negative' if label in negative_emotions else 'Positive' if label in positive_emotions else 'Neutral' for label in emotion_train['Label']]

# %%
emotion_train.head(20)
# Out:
#                                              Sentence     Label Sentiment
# 0                             i didnt feel humiliated   sadness  Negative
# 1   i can go from feeling so hopeless to so damned...   sadness  Negative
# 2    im grabbing a minute to post i feel greedy wrong     anger  Negative
# 3   i am ever feeling nostalgic about the fireplac...      love  Positive
# 4                                i am feeling grouchy     anger  Negative
# 5   ive been feeling a little burdened lately wasn...   sadness  Negative
# 6   ive been taking or milligrams or times recomme...  surprise   Neutral
# 7   i feel as confused about life as a teenager or...      fear  Negative
# 8   i have been with petronas for years i feel tha...       joy  Positive
# 9                                 i feel romantic too      love  Positive
# 10  i feel like i have to make the suffering i m s...   sadness  Negative
# 11  i do feel that running is a divine experience ...       joy  Positive
# 12  i think it s the easiest time of year to feel ...     anger  Negative
# 13                 i feel low energy i m just thirsty   sadness  Negative
# 14  i have immense sympathy with the general point...       joy  Positive
# 15    i do not feel reassured anxiety is on each side       joy  Positive
# 16               i didnt really feel that embarrassed   sadness  Negative
# 17            i feel pretty pathetic most of the time   sadness  Negative
# 18  i started feeling sentimental about dolls i ha...   sadness  Negative
# 19  i now feel compromised and skeptical of the va...      fear  Negative

# %%
emojis.head(20)
# Out:
#    Emoji  Occurrences                              Unicode name Sentiment
# 0      😂        14622                    FACE WITH TEARS OF JOY  Positive
# 1      ❤         8050                         HEAVY BLACK HEART  Positive
# 2      ♥         7144                          BLACK HEART SUIT  Positive
# 3      😍         6359       SMILING FACE WITH HEART-SHAPED EYES  Positive
# 4      😭         5526                        LOUDLY CRYING FACE  Negative
# 5      😘         3648                      FACE THROWING A KISS  Positive
# 6      😊         3186            SMILING FACE WITH SMILING EYES  Positive
# 7      👌         2925                              OK HAND SIGN  Positive
# 8      💕         2400                                TWO HEARTS  Positive
# 9      👏         2336                       CLAPPING HANDS SIGN  Positive
# 10     😁         2189           GRINNING FACE WITH SMILING EYES  Positive
# 11     ☺         2062                        WHITE SMILING FACE  Positive
# 12     ♡         1975                          WHITE HEART SUIT  Positive
# 13     👍         1854                            THUMBS UP SIGN  Positive
# 14     😩         1808                                WEARY FACE  Negative
# 15     🙏         1539                  PERSON WITH FOLDED HANDS  Positive
# 16     ✌         1534                              VICTORY HAND  Positive
# 17     😏         1522                             SMIRKING FACE   Neutral
# 18     😉         1521                              WINKING FACE  Positive
# 19     🙌         1506  PERSON RAISING BOTH HANDS IN CELEBRATION  Positive

# %%
# merge the two tables on 'Sentiment' column
emotion_emoji_merged = emotion_train.merge(emojis)

# %%
emotion_emoji_merged.head()
# Out:
#                   Sentence    Label Sentiment Emoji  Occurrences  \
# 0  i didnt feel humiliated  sadness  Negative     😭         5526
# 1  i didnt feel humiliated  sadness  Negative     😩         1808
# 2  i didnt feel humiliated  sadness  Negative     😒         1385
# 3  i didnt feel humiliated  sadness  Negative     😔         1205
# 4  i didnt feel humiliated  sadness  Negative     😡          756
#
#          Unicode name
# 0  LOUDLY CRYING FACE
# 1          WEARY FACE
# 2       UNAMUSED FACE
# 3        PENSIVE FACE
# 4        POUTING FACE

# %%
# shape after merging (4M)
emotion_emoji_merged.shape
# Out:
# (4370002, 6)

# %%
emotion_emoji_merged.isna().sum()
# Out:
# Sentence        0
# Label           0
# Sentiment       0
# Emoji           0
# Occurrences     0
# Unicode name    0
# dtype: int64

# %%
emotion_emoji_merged.duplicated().sum()
# Out:
# 481

# %%
#check distribution of data based on labels
print(emotion_emoji_merged.Label.value_counts())
# Out:
# joy         2579122
# love         627224
# sadness      503928
# anger        233172
# surprise     217360
# fear         209196
# Name: Label, dtype: int64

# %%
# save the merged dataset as csv
# emotion_emoji_merged.to_csv('../data/sentence_emoji_sentiment_merged.csv', index=False)

# %% [markdown]
# ## Explore merged dataset
